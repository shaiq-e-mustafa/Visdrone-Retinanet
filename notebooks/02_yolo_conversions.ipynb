# %% [markdown]
# ### Yolo Converter

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent

sys.path.append(str(ROOT))

# %%
from src.utils.get_img_ann import list_stems
import os
DATASET_DIR = 'dataset'
img_dir = os.path.join('..', DATASET_DIR, "raw", "images")
ann_dir = os.path.join('..', DATASET_DIR, "raw", "annotations")

pairs = list_stems(img_dir, ann_dir)

# %%
from src.utils.split_pairs import split_pairs

split_pairs(pairs=pairs)
# Out:
# Total: 6471 | train: 4529 | val: 647 | test: 1295
# {'train': [('..\\dataset\\raw\\images\\9999999_00731_d_0000333.jpg',
#    '..\\dataset\\raw\\annotations\\9999999_00731_d_0000333.txt'),
#   ('..\\dataset\\raw\\images\\9999950_00000_d_0000014.jpg',
#    '..\\dataset\\raw\\annotations\\9999950_00000_d_0000014.txt'),
#   ('..\\dataset\\raw\\images\\9999982_00000_d_0000045.jpg',
#    '..\\dataset\\raw\\annotations\\9999982_00000_d_0000045.txt'),
#   ('..\\dataset\\raw\\images\\9999962_00000_d_0000098.jpg',
#    '..\\dataset\\raw\\annotations\\9999962_00000_d_0000098.txt'),
#   ('..\\dataset\\raw\\images\\0000140_02477_d_0000006.jpg',
#    '..\\dataset\\raw\\annotations\\0000140_02477_d_0000006.txt'),
#   ('..\\dataset\\raw\\images\\9999981_00000_d_0000147.jpg',
#    '..\\dataset\\raw\\annotations\\9999981_00000_d_0000147.txt'),
#   ('..\\dataset\\raw\\images\\9999999_00307_d_0000136.jpg',
#    '..\\dataset\\raw\\annotations\\9999999_00307_d_0000136.txt'),
# ...
